# %%
# %sql SHOW CATALOGS;

# %%
# %sql
SELECT current_catalog();

# %%
# %sql
SHOW SCHEMAS IN covid_reporting_ws_2627 ;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS covid;
SHOW SCHEMAS;

# %%
# %sql
CREATE EXTERNAL LOCATION covid_reporting_el_lookup
URL 'abfss://lookup@covidreportingdl2627.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `covid-reporting-sc`);

# %%
# %sql
CREATE EXTERNAL LOCATION covid_reporting_el_processed
URL 'abfss://processed@covidreportingdl2627.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `covid-reporting-sc`);

# %%
# %sql
CREATE EXTERNAL LOCATION covid_reporting_el_raw
URL 'abfss://raw@covidreportingdl2627.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `covid-reporting-sc`);

# %%
# Replace 'lookup' with your container name if needed
dbutils.fs.ls("abfss://raw@covidreportingdl2627.dfs.core.windows.net/population")

# %%
df_raw_population = spark.read.csv(
    "abfss://raw@covidreportingdl2627.dfs.core.windows.net/population/population_by_age_tsv", 
    sep=r'\t', 
    header=True
)

# %%
df_raw_population.display()
